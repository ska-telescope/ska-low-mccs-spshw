# %% [markdown]
# # A how to guide for running self-check tests on the station.
#
# You can find the test in `/home/gsc/SKAO/ska-low-mccs-spshw/src/ska_low_mccs_spshw/station/tests`.
#
# This group of tests are meant to run on an actual k8s deployment.
#
# ## Setup
#
# In general you want the devices used for the test in engineering mode. This part of the code loops over all proxies and checks their mode, If they are not in in engineering mode, then they have admin mode changed. 30 seconds later the code writes

# %%
from ska_control_model import AdminMode
from datetime import datetime, timedelta
from pathlib import Path
import tango
import time
import json

db = tango.Database()
all_devices_strings = db.get_device_exported("low-mccs/*")
recheck = False
for device_str in all_devices_strings:
    device = tango.DeviceProxy(device_str)
    if device.adimMode != 2:
        print(f"{device_str} is in {device.state()} state, turning it to Engineering mode")
        device.adminMode = 2
        recheck = True
    else:
        print(f"{device_str} is in {device.state()} state")

if recheck:
    # this part is just a lazy progress bar.
    for i in range(30):
        print(f"Starting devices in progress {i/0.3:.2f}%", end="")
        time.sleep(1)
        print("\r", end="")
    
    # print everything out again
    for device_str in all_devices_strings:
        device = tango.DeviceProxy(device_str)
        print(f"{device_str} is in {device.state()} state")

# get the station, daq and tpm devices
station = tango.DeviceProxy("low-mccs/spsstation/stfc-ral-software")
print(f"{station.state() = }")

# daq = tango.DeviceProxy("low-mccs/daqreceiver/stfc-ral-software-bandpass")
# tpms = [ tango.DeviceProxy(tpm_str) for tpm_str in db.get_device_exported("low-mccs/tile/*") ]

# %% [markdown]
# The tests are set up in such a way that they can only run when all devices used are in Engineer mode. Here I just set up all devices to Engineer mode. It's the same method used before, but note that adminMode is 2 now. For some reason setting admimode to 2 from the start doesn't work.

# %%
all_devices_strings = db.get_device_exported("low-mccs/*")
recheck = False

for device_str in all_devices_strings:
    device = tango.DeviceProxy(device_str)
    print(f"{device_str} is in {device.state()} state, turning it to Engineering mode")
    device.adminMode = 2
    recheck = True

if recheck: # print everything out again after 30 sec.
    for i in range(30):
        # this part is just a lazy progress bar.
        print(f"Starting devices in progress {i/0.3:.2f}%", end="")
        time.sleep(1)
        print("\r", end="")
    for device_str in all_devices_strings:
        device = tango.DeviceProxy(device_str)
        print(f"{device_str} is in {device.AdminMode} state")

# %% [markdown]
# ## Antenna Buffer Tests

# %%
print(station.DescribeTest("TestAntennaBuffer"))
station.RunTest(json.dumps({"test_name" : "TestAntennaBuffer"}))
print(station.longrunningcommandsinqueue)
while any(station.longrunningcommandsinqueue):
    time.sleep(0.1)
print(station.testlogs)

# %% [markdown]
# ## Troubleshooting steps
#
# For those moments when things do go wrong.
#
# ### Tpms syncronization
#
# The tpms must be syncronized, and sometimes they just don't do that.
# This is a bit of code that tries to reset them by:
#
# 1. Cheking if they are online then starting them.
# 2. Then sets station in standby mode and then on again.
# 3. Finally, starts statin aquisition, which should trigger the tpms to syncronize again.

# %%
def check_tpms(tpms):
    """Check the state of tpms and return a list of those that are not online."""
    bad_tpms = []
    for tpm in tpms:
        if tpm.state() != AdminMode.ONLINE:
            bad_tpms.append(tpm)
    return bad_tpms

def fix_tpms(tpms):
    """Attempt to fix tpms that are not online."""
    bad_tpms = check_tpms(tpms)
    for i in range(3):
        if bad_tpms == []:
            break
        else:
            print(f"Atempt {i+1} at fixing tpms")
        for tpm in bad_tpms:
            if tpm.state() != AdminMode.ONLINE:
                tpm.ON()
        time.sleep(10)
        bad_tpms = check_tpms(tpms)
        for tpm in bad_tpms:
            print(f"{tpm.name()} is in {tpm.state()} state")
    if any(bad_tpms):
        return False
    return True

def wait2finish(device):
    while any(device.longrunningcommandsinqueue):
        print(f"{device.longrunningcommandsinqueue}%", end="")
        time.sleep(0.1)
        print("\r", end="")
    device.state()

def sync_tpms(tpms):
    if any(station.TileProgrammingState) != 'Syncronized':
        # Try and reboot tpms, if that fails, reboot station
        if not fix_tpms(tpms):
            station.standby()
            wait2finish(station)
            station.ON()
            wait2finish(station)
            if not fix_tpms(tpms):
                return "Failed to sync"
        else:
            time.sleep(5)
    
    if any(station.TileProgrammingState) != 'Syncronized':    
        station.StartAcquisition('{}')
        daq_status = json.loads(daq.DaqStatus())
        daq.stop()
        wait2finish(daq)
        daq.Configure(
            json.dumps(
                {
                    "directory": "/",
                    "nof_tiles": len(tpms),
                    "description": station.name(),
                }
            )
        )
        daq.start('{"modes_to_start": "RAW_DATA"}')
        wait2finish(daq)
        
        daq_status = json.loads(daq.DaqStatus())
        print(daq_status)
        start_time = datetime.utcnow() + timedelta(seconds=5)
        station.SendDataSamples(
            json.dumps(
                {
                    "data_type": "raw",
                    "start_time": start_time.strftime("%Y-%m-%dT%H:%M:%S.%fZ"),
                    "sync": True,
                }
            )
        )

        seconds_until_start = (start_time - datetime.utcnow()).total_seconds()
        if seconds_until_start > 0:
            print(f"Waiting {seconds_until_start} seconds for scan to start")
            time.sleep(seconds_until_start)
        for i in range(120):
            if all(station.TileProgrammingState) == 'Syncronized':
                break
            print(f"{station.TileProgrammingState}", end="")
            time.sleep(0.5)
            print("\r", end="")

station = tango.DeviceProxy("low-mccs/spsstation/stfc-ral-software")
daq = tango.DeviceProxy("low-mccs/daqreceiver/stfc-ral-software-bandpass")
tpms = [ tango.DeviceProxy(tpm_str) for tpm_str in db.get_device_exported("low-mccs/tile/*") ]
print(sync_tpms(tpms))
